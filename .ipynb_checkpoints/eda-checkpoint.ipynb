# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Fri Jun 30 08:36:08 2017

@author: jerry
"""
from sklearn import datasets
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
iris = datasets.load_iris()

x = iris.data
y = iris.target
df = pd.DataFrame(x, columns=iris.feature_names)

print(df)
#看欄位與屬性
# df.info()

### Viewing Data(pd基本指令集)
#df.dtypes
#df.describe()
#df.info()（矩陣訊息）
#df.head(2)（取頭）
#df.tail(1)（取尾）
#df.T（矩陣轉換）


##
#Renaming columns in pandas(pd基本指令集2)
#df.dtypes
#df.columns = ['sepal_length','sepal_width','petal_length','petal_width']（改欄位名）
#df.sort_values(by='sepal_length', ascending=False)（排序）
#ascending=FALSE 從大排到小，反之從小排到大

#### Selection(pd取值)
#df['sepal_length'].head(9)
#df[0:3]（3rows）
## Selection by Label
#df.loc[:,['sepal_length','sepal_width']].head(5)（取雙欄位）
## Selection by Position
#df.iloc[1:10,0:2] [列,行]（取列，取行）

#Filling missing data
#df.dropna(how='any')
#df1.fillna(value=5)

### Merge
#xx = x + y
#xx_pd=pd.DataFrame(xx)
#pd.concat([xx_pd,xx_pd],axis=1) #行合併
#pd.concat([xx_pd,xx_pd],axis=0) #列合併

#df.drop(df.index[[0,1]])

pd.scatter_matrix(df, c = y, figsize=[8,8],
                      s=150, marker='D')
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# 5                  5.4               3.9                1.7               0.4
# 6                  4.6               3.4                1.4               0.3
# 7                  5.0               3.4                1.5               0.2
# 8                  4.4               2.9                1.4               0.2
# 9                  4.9               3.1                1.5               0.1
# 10                 5.4               3.7                1.5               0.2
# 11                 4.8               3.4                1.6               0.2
# 12                 4.8               3.0                1.4               0.1
# 13                 4.3               3.0                1.1               0.1
# 14                 5.8               4.0                1.2               0.2
# 15                 5.7               4.4                1.5               0.4
# 16                 5.4               3.9                1.3               0.4
# 17                 5.1               3.5                1.4               0.3
# 18                 5.7               3.8                1.7               0.3
# 19                 5.1               3.8                1.5               0.3
# 20                 5.4               3.4                1.7               0.2
# 21                 5.1               3.7                1.5               0.4
# 22                 4.6               3.6                1.0               0.2
# 23                 5.1               3.3                1.7               0.5
# 24                 4.8               3.4                1.9               0.2
# 25                 5.0               3.0                1.6               0.2
# 26                 5.0               3.4                1.6               0.4
# 27                 5.2               3.5                1.5               0.2
# 28                 5.2               3.4                1.4               0.2
# 29                 4.7               3.2                1.6               0.2
# ..                 ...               ...                ...               ...
# 120                6.9               3.2                5.7               2.3
# 121                5.6               2.8                4.9               2.0
# 122                7.7               2.8                6.7               2.0
# 123                6.3               2.7                4.9               1.8
# 124                6.7               3.3                5.7               2.1
# 125                7.2               3.2                6.0               1.8
# 126                6.2               2.8                4.8               1.8
# 127                6.1               3.0                4.9               1.8
# 128                6.4               2.8                5.6               2.1
# 129                7.2               3.0                5.8               1.6
# 130                7.4               2.8                6.1               1.9
# 131                7.9               3.8                6.4               2.0
# 132                6.4               2.8                5.6               2.2
# 133                6.3               2.8                5.1               1.5
# 134                6.1               2.6                5.6               1.4
# 135                7.7               3.0                6.1               2.3
# 136                6.3               3.4                5.6               2.4
# 137                6.4               3.1                5.5               1.8
# 138                6.0               3.0                4.8               1.8
# 139                6.9               3.1                5.4               2.1
# 140                6.7               3.1                5.6               2.4
# 141                6.9               3.1                5.1               2.3
# 142                5.8               2.7                5.1               1.9
# 143                6.8               3.2                5.9               2.3
# 144                6.7               3.3                5.7               2.5
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
# sepal length (cm)    150 non-null float64
# sepal width (cm)     150 non-null float64
# petal length (cm)    150 non-null float64
# petal width (cm)     150 non-null float64
# dtypes: float64(4)
# memory usage: 4.8 KB
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1131bc978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116552ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1165ac400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1166159e8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x116631be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116631cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11673af98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1167958d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1167facc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1168567f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1168bd908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11691d390>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x116985898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1169dfef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116a4d518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116aa3ef0>]], dtype=object)
